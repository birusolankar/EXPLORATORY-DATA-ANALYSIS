# %% [markdown]
# <a href="https://colab.research.google.com/github/birusolankar/EXPLORATORY-DATA-ANALYSIS/blob/main/Accident_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("/content/Road Accident Data.xlsx")

# %%
df.to_csv("/content/Road_Accident_Data.csv", index=False)

# %%
df.head()
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0      BS0000001    2021-01-01    Thursday  Give way or uncontrolled
# 1      BS0000002    2021-01-05      Monday  Give way or uncontrolled
# 2      BS0000003    2021-01-04      Sunday  Give way or uncontrolled
# 3      BS0000004    2021-01-05      Monday       Auto traffic signal
# 4      BS0000005    2021-01-06     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                None  ...
# ...

# %%
df['Light_Conditions'].value_counts()
# Out:
# Daylight                       227286
# Darkness - lights lit           60093
# Darkness - no lighting          16528
# Darkness - lighting unknown      2924
# Darkness - lights unlit          1142
# Name: Light_Conditions, dtype: int64

# %%
# count of records
df.count()
# Out:
# Accident_Index                307973
# Accident Date                 307973
# Day_of_Week                   307973
# Junction_Control              307973
# Junction_Detail               307973
# Accident_Severity             307973
# Latitude                      307973
# Light_Conditions              307973
# Local_Authority_(District)    307973
# Carriageway_Hazards           307970
# Longitude                     307973
# Number_of_Casualties          307973
# Number_of_Vehicles            307973
# Police_Force                  307973
# Road_Surface_Conditions       307973
# Road_Type                     307973
# Speed_limit                   307973
# Time                          307956
# Urban_or_Rural_Area           307973
# Weather_Conditions            307973
# Vehicle_Type                  307973
# dtype: int64

# %%
# lets scan the data
df.head(5) # top five records
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0      BS0000001    2021-01-01    Thursday  Give way or uncontrolled
# 1      BS0000002    2021-01-05      Monday  Give way or uncontrolled
# 2      BS0000003    2021-01-04      Sunday  Give way or uncontrolled
# 3      BS0000004    2021-01-05      Monday       Auto traffic signal
# 4      BS0000005    2021-01-06     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                None  ...
# ...

# %%
df.tail(5) # bottom three records
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 307968      BS0307969    2022-02-18    Thursday  Data missing or out of range
# 307969      BS0307970    2022-02-21      Sunday  Data missing or out of range
# 307970      BS0307971    2022-02-23     Tuesday      Give way or uncontrolled
# 307971      BS0307972    2022-02-23     Tuesday      Give way or uncontrolled
# 307972      BS0307973    2022-02-28      Sunday      Give way or uncontrolled
#
#                             Junction_Detail Accident_Severity   Latitude  \
# 307968  Not at junction or within 20 metres            Slight  57.374005
# 307969  Not at junction or within 20 metres            Slight  57.232273
# 307970              T or staggered junction            Slight  57.585044
# 307971              T or staggered junction           Serious  57.214898
# 307972              T or staggered junction           Serious  57.575210
#
# ...

# %%
df.sample(5) # any records from data sets
# Out:
#        Accident_Index Accident Date Day_of_Week  \
# 115162      BS0115163    2021-06-17   Wednesday
# 171564      BS0171565    2022-02-18    Thursday
# 169709      BS0169710    2022-03-27    Saturday
# 138937      BS0138938    2021-04-15   Wednesday
# 203569      BS0203570    2022-07-18      Sunday
#
#                            Junction_Control  \
# 115162         Data missing or out of range
# 171564         Data missing or out of range
# 169709             Give way or uncontrolled
# 138937             Give way or uncontrolled
# 203569  Not at junction or within 20 metres
#
#                             Junction_Detail Accident_Severity   Latitude  \
# 115162  Not at junction or within 20 metres            Slight  50.914872
# 171564  Not at junction or within 20 metres            Slight  51.550396
# 169709              T or staggered junction            Slight  51.596688
# 138937                           Roundabout            Slight  51.502077
# ...

# %%
# gives the number of records and columns
df.shape
# Out:
# (307973, 21)

# %%
# gives the overall information of the datasets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307973 non-null  object
#  1   Accident Date               307973 non-null  datetime64[ns]
#  2   Day_of_Week                 307973 non-null  object
#  3   Junction_Control            307973 non-null  object
#  4   Junction_Detail             307973 non-null  object
#  5   Accident_Severity           307973 non-null  object
#  6   Latitude                    307973 non-null  float64
#  7   Light_Conditions            307973 non-null  object
#  8   Local_Authority_(District)  307973 non-null  object
#  9   Carriageway_Hazards         307970 non-null  object
#  10  Longitude                   307973 non-null  float64
#  11  Number_of_Casualties        307973 non-null  int64
# ...

# %%
# lets see the statistical summary of the of the datasets
df.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles  \
# count  307973.000000  307973.000000         307973.000000       307973.000000
# mean       52.487005      -1.368884              1.356882            1.829063
# std         1.339011       1.356092              0.815857            0.710477
# min        49.914488      -7.516225              1.000000            1.000000
# 25%        51.485248      -2.247937              1.000000            1.000000
# 50%        52.225943      -1.349258              1.000000            2.000000
# 75%        53.415517      -0.206810              1.000000            2.000000
# max        60.598055       1.759398             48.000000           32.000000
#
#          Speed_limit
# count  307973.000000
# mean       38.866037
# std        14.032933
# min        10.000000
# 25%        30.000000
# 50%        30.000000
# 75%        50.000000
# max        70.000000
